# %% [markdown]
# #### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#006600; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #003300"> 🎫  DATA Scientists Salary Analysis</p>
# <img src ="https://thumbs.dreamstime.com/b/data-science-deep-learning-artificial-intelligence-analysis-internet-modern-technology-concept-130068639.jpg" align="center" width=700 />

# %% [markdown]
# #### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#006600; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #003300"> 🎫 INDEX</p>
# - Introduction
# - About Data
# - Data Cleaning
# - Asking Questions

# %% [markdown]
# ### <p style="font-family:JetBrains Mono; font-weight:bold; letter-spacing: 2px; color:#006600; font-size:140%; text-align:left;padding: 0px; border-bottom: 3px solid #003300"> 🎫 Introduction</p>
# **Data science is the domain of study that deals with vast volumes of data using modern tools and techniques to find unseen patterns, derive meaningful information, and make business decisions. Data science uses complex machine learning algorithms to build predictive models.
# In this project, we will be using the “Data Science Job Salaries"data set. We will explore the data, and then visualize it using various methods. We will also make predictions regarding salaries in the various data science careers around the world.**

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
print(" Libries Imported Successfully")
# Out:
#  Libries Imported Successfully

# %% [markdown]
# ## About data
# - read data
# - shape of data
# - head and tail
# - data info
# - data dtypes
# - checking null values

# %% [markdown]
# ### Read data

# %%
df=pd.read_csv("/kaggle/input/data-science-job-salaries/ds_salaries.csv")
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    607
# Name: count, dtype: int64

# %% [markdown]
# ### shape of data

# %%
df.shape
# Out:
# (607, 12)

# %% [markdown]
# ### Head of data

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df["company_location"].value_counts()
# Out:
# company_location
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# BR      3
# AE      3
# MX      3
# AU      3
# TR      3
# DK      3
# IT      2
# CZ      2
# SI      2
# RU      2
# CH      2
# NG      2
# CN      2
# BE      2
# VN      1
# EE      1
# AS      1
# DZ      1
# MY      1
# MD      1
# KE      1
# SG      1
# CO      1
# IR      1
# CL      1
# MT      1
# IL      1
# UA      1
# IQ      1
# RO      1
# HR      1
# NZ      1
# HU      1
# HN      1
# IE      1
# Name: count, dtype: int64

# %%
df["employment_type"].value_counts()
# Out:
# employment_type
# FT    588
# PT     10
# CT      5
# FL      4
# Name: count, dtype: int64

# %% [markdown]
# ### Tail of data

# %%
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %% [markdown]
# ### Data info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %% [markdown]
# ### Data dtypes

# %%
df.dtypes.value_counts()
# Out:
# object    7
# int64     5
# Name: count, dtype: int64

# %% [markdown]
# ### Data Columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %% [markdown]
# ### checking null values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ## Data Cleaning
# - Remove unnecessary columns and rows
# - Renaming columns
# - Creating new columns
# - Clean column data
# - Removing Duplicate row and columns

# %%
df["work_year"].value_counts()
# Out:
# work_year
# 2022    318
# 2021    217
# 2020     72
# Name: count, dtype: int64

# %% [markdown]
# ## Creating new columns

# %%
df[["employee_residence","company_location"]].value_counts()
# Out:
# employee_residence  company_location
# US                  US                  330
# GB                  GB                   43
# CA                  CA                   28
# IN                  IN                   24
# DE                  DE                   23
#                                        ...
# HN                  HN                    1
# HK                  GB                    1
# GR                  US                    1
#                     DK                    1
# VN                  VN                    1
# Name: count, Length: 90, dtype: int64

# %%
df1=df[df["employee_residence"]!=df["company_location"]]

# %%
df1[["employee_residence","company_location"]].value_counts()
# Out:
# employee_residence  company_location
# IN                  US                  4
# BR                  US                  3
# PK                  DE                  2
# RU                  US                  2
# AR                  MX                  1
# PT                  LU                  1
# MY                  US                  1
# NL                  DE                  1
# PH                  US                  1
# PK                  US                  1
# PL                  GB                  1
# PR                  US                  1
# RO                  GB                  1
# PT                  US                  1
# JE                  CN                  1
# RO                  US                  1
# RS                  DE                  1
# SG                  IL                  1
# TN                  CZ                  1
# US                  CA                  1
#                     FR                  1
# ...

# %%
def overseas(x,y):
    #print(x,y)
    #print(type(x))
    if x==y:
        return 0
    else:
        return 1

# %%
df["overseas"]=df[["employee_residence","company_location"]].apply\
(lambda z:overseas(z["employee_residence"],z["company_location"]),axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size  overseas
# 0                 DE             0               DE            L         0
# ...

# %% [markdown]
# ### Clean column data

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# overseas               int64
# dtype: object

# %% [markdown]
# ### Seperating object columns

# %%
cat_col=df.dtypes[df.dtypes=="object"].index
cat_col
# Out:
# Index(['experience_level', 'employment_type', 'job_title', 'salary_currency',
#        'employee_residence', 'company_location', 'company_size'],
#       dtype='object')

# %%
num_col=df.dtypes[df.dtypes!="object"].index
num_col
# Out:
# Index(['Unnamed: 0', 'work_year', 'salary', 'salary_in_usd', 'remote_ratio',
#        'overseas'],
#       dtype='object')

# %%
df[cat_col]
# Out:
#     experience_level employment_type                   job_title  \
# 0                 MI              FT              Data Scientist
# 1                 SE              FT  Machine Learning Scientist
# 2                 SE              FT           Big Data Engineer
# 3                 MI              FT        Product Data Analyst
# 4                 SE              FT   Machine Learning Engineer
# ..               ...             ...                         ...
# 602               SE              FT               Data Engineer
# 603               SE              FT               Data Engineer
# 604               SE              FT                Data Analyst
# 605               SE              FT                Data Analyst
# 606               MI              FT                AI Scientist
#
#     salary_currency employee_residence company_location company_size
# 0               EUR                 DE               DE            L
# ...

# %%
for col in cat_col:
    print(col,df[col].value_counts())
# Out:
# experience_level experience_level
# SE    280
# MI    213
# EN     88
# EX     26
# Name: count, dtype: int64
# employment_type employment_type
# FT    588
# PT     10
# CT      5
# FL      4
# Name: count, dtype: int64
# job_title job_title
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# ...

# %%
def count_plt(df = df):
  
  cat_col = df.dtypes[df.dtypes == "object"].index
  for col in cat_col:
    count_series = df[col].value_counts().head(10)
    sns.countplot(x=col,data=df,order=count_series.index)
    plt.xticks(rotation=90)
    plt.show()

# %%
count_plt(df)

# %% [markdown]
# ### Asking Questions

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### This DataFrame contains 844 duplicate rows

# %%
df_duplicated=df.drop_duplicates()
df_duplicated.shape,df.shape
# Out:
# ((607, 13), (607, 13))

# %% [markdown]
# #### Dropping the duplicated rows in the data frame and after dropping the duplicate rows the remaining rows will be 2162

# %% [markdown]
# ### 1. Average salary based on job_title and employee_type

# %%
temp_df=df_duplicated.groupby(["employment_type","job_title"])["salary_in_usd"].mean().sort_values(ascending=False).reset_index()
temp_df_new = pd.DataFrame({
    'employment_type':[],
    'job_title':[],
    'salary_in_usd' : []
})
for type in temp_df["employment_type"].unique():
    # print(temp_df[temp_df["employment_type"]==type].head())
     temp_df_new = pd.concat([temp_df[temp_df["employment_type"] == type].head(), temp_df_new])

temp_df_new
# Out:
#    employment_type                           job_title  salary_in_usd
# 47              PT                       Data Engineer   62349.000000
# 49              PT                      Data Scientist   60834.500000
# 56              PT            Computer Vision Engineer   28609.000000
# 58              PT                         ML Engineer   15966.000000
# 60              PT                        AI Scientist   12000.000000
# 33              FL                      Data Scientist  100000.000000
# 50              FL            Computer Vision Engineer   60000.000000
# 57              FL                       Data Engineer   20000.000000
# 61              FL          Machine Learning Scientist   12000.000000
# 1               FT                 Data Analytics Lead  405000.000000
# 2               FT             Principal Data Engineer  328333.333333
# 3               FT              Financial Data Analyst  275000.000000
# ...

# %%
temp_df = df_duplicated.groupby(['employment_type', 'job_title'])["salary_in_usd"].mean().sort_values(ascending = False).reset_index()

for type in temp_df["employment_type"].unique():
    sns.barplot(data  = temp_df[temp_df["employment_type"] == type].head()\
              , x = "job_title", y = "salary_in_usd", hue = "employment_type")
    plt.title(f"Top 5 average salaries based on job title for {type}" )
    plt.xticks(rotation = 45)
    plt.show()

# %% [markdown]
# CONCLUSION:   As we can see by our observation that more companies are realizing that they need a solid data infrastructure to add value to their business before hiring a Data Scientist or a Data ML Engineer.

# %% [markdown]
# ### 2. Top 5 Average salary based on job title and exp level

# %%
temp_df=df_duplicated.groupby(['experience_level','job_title'])["salary_in_usd"].mean()\
.sort_values(ascending=False).reset_index()
for exp in temp_df["experience_level"].unique():
    print(temp_df[temp_df["experience_level"]==exp].head())
# Out:
#    experience_level                 job_title  salary_in_usd
# 0                EX   Principal Data Engineer  600000.000000
# 2                EX  Principal Data Scientist  416000.000000
# 6                EX             Data Engineer  245500.000000
# 7                EX              Head of Data  232500.000000
# 11               EX  Director of Data Science  199586.333333
#    experience_level                           job_title  salary_in_usd
# 1                MI              Financial Data Analyst  450000.000000
# 10               MI                Data Science Manager  200000.000000
# 17               MI  Applied Machine Learning Scientist  178800.000000
# 21               MI                      Data Architect  166666.666667
# 24               MI                        AI Scientist  160000.000000
#    experience_level                   job_title  salary_in_usd
# 3                SE         Data Analytics Lead  405000.000000
# ...

# %%
temp_df = df_duplicated.groupby(['experience_level', 'job_title'])["salary_in_usd"].mean().sort_values(ascending = False).reset_index()

for exp in temp_df["experience_level"].unique():
    sns.barplot(data  = temp_df[temp_df["experience_level"] == exp].head()\
              , x = "job_title", y = "salary_in_usd", hue = "experience_level")
    plt.title(f"Top 5 average salaries based on job title for {exp} level")
    plt.xticks(rotation = 45)
    plt.show()

# %% [markdown]
#  CONCLUSION:As we can see by our observation that Deep Learning engineer have more scope in the entry level(Experience), Data infrastructure Engineer in MI, Data Analytics Lead in SE and Principal Data Scientist in the EX.

# %% [markdown]
# ## **3. Trending job_titles in india year wise**

# %%
temp_df = df[["work_year", "job_title"]][df["company_location"]=="IN"].value_counts().reset_index(name = "jobs")

for year in temp_df["work_year"].unique():
    data = temp_df[temp_df["work_year"] == year].head()
    sns.barplot(data  = data\
              , x = "job_title", y = "jobs")
    plt.title(f"Top 5 popular jobs for  year: {year}")
    plt.xticks(rotation = 45)
    plt.show()

# %% [markdown]
# CONCLUSION:As we can see by our observation that Data Scientist have more scope in the Year 2021,2022,2023 so overall Pursuing a career as data scientist requires a combination of technical skills ,analytical skills and communication skills.

# %% [markdown]
# ## **4. Top 5 overseas company locations that employed indians**

# %%
temp_df=df[(df["overseas"]==1) & (df["employee_residence"]=="IN")]

sns.countplot(data=df,x=temp_df["company_location"],order=temp_df["company_location"].value_counts().index)
# Out:
# <Axes: xlabel='company_location', ylabel='count'>

# %% [markdown]
# **It shows that the (US,SG,AS,ID,CH) are the top 5 overseas company location that employed indians**

# %% [markdown]
# ## **5. Company location on basis of Size**

# %%
df[[ "company_size","company_location"]].value_counts()
# Out:
# company_size  company_location
# M             US                  218
# L             US                  106
# S             US                   31
# M             GB                   31
#               CA                   16
#                                  ...
#               IL                    1
# L             GR                    1
# M             LU                    1
#               PT                    1
# L             AE                    1
# Name: count, Length: 84, dtype: int64

# %%
temp_df=df[["company_location", "company_size"]].value_counts().reset_index(name = "count")
for size in temp_df["company_size"].unique():
    data = temp_df[temp_df["company_size"] == size].head()
    sns.barplot(data  = data\
              , x = "company_location", y = "count")
    plt.title(f"Top 5 popular jobs for  year: {size}")
    plt.xticks(rotation = 45)
    plt.show()

# %% [markdown]
# ### As we can see by our observation that US location have every type of company small,medium,large.

# %% [markdown]
# ## **6. Top 5 job title based on company size and emp_type for freshers**

# %%
temp_df = df[["job_title", "company_size","employment_type"]][df["experience_level"]=="EN"].value_counts().reset_index(name = "count")

try:
    for size in temp_df["company_size"].unique():
        for tp in temp_df["employment_type"].unique():
            data = temp_df[(temp_df["company_size"] == size) & (temp_df["employment_type"] == tp)].head()

            sns.barplot(data = data\
                  , x = "job_title", y ="count")
            plt.title(f"Top 5 popular jobs for {size}, {tp}")
            plt.xticks(rotation = 45)
            plt.show()
except:
    print()

# %% [markdown]
# CONCLUSION:
#            We can see that Machine Learning Engineer and Data Analyst are the two leading job titles for data people with Data            Engineer becoming more popular as of late most probably because more and more companies are realizing that they                need a solid data infrastructure to add value to their business before hiring a Data Scientist or a Data Analyst              and Machine Learning Engineer.

# %% [markdown]
# ## **7. Average pay based on job_title and company size**

# %%
temp_df=df.groupby([ "company_size","job_title"])["salary_in_usd"].mean().reset_index(name = "salary")
for size in temp_df["company_size"].unique():
    data = temp_df[temp_df["company_size"] == size].head()
    sns.barplot(data  = data\
              , x = "job_title", y = "salary")
    plt.title(f"Top 5 popular jobs for  year: {size}")
    plt.xticks(rotation = 45)
    plt.show()

# %% [markdown]
# CONCLUSION:As we can see by our observation that small and medium company hires 3D Computer Vision Researcher and large company hires the Al developer.

# %% [markdown]
# ## **8. Trending job_titles,year wise**

# %%
temp_df = df[["work_year", "job_title"]].value_counts().reset_index(name = "jobs")

for year in temp_df["work_year"].unique():
    data = temp_df[temp_df["work_year"] == year].head()
    sns.barplot(data  = data\
              , x = "job_title", y = "jobs")
    plt.title(f"Top 5 popular jobs for  year: {year}")
    plt.xticks(rotation = 45)
    plt.show()

# %% [markdown]
# CONCLUSION: As we can see by our observation that the companies are realizing that they need a solid data infrastructure to add value to their business before hiring a Data Scientist or a Data Data Engineer.
